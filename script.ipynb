# %% [markdown]
# ## Guided Project: Visualizing Earnings Based On College Majors

# %% [markdown]
# Learn how to use pandas to quickly create visualizations.
#
# Objectives
# - Practice your data visualization skills.
# - Learn how to use pandas and matplotlib together.
# - Learn to adjust your plots for readability.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
grads = pd.read_csv('recent-grads.csv')

# %%
grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Lets clean the missing values from the dataset.

# %%
grads.shape
# Out:
# (172, 21)

# %%
grads = grads.dropna()

# %%
grads.shape
# Out:
# (172, 21)

# %% [markdown]
# # Visulazing data using different columns

# %%
grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
grads.plot(x='Sample_size', y='Median', kind='scatter')

# %%
grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %%
grads.plot(x='Full_time', y='Median', kind = 'scatter')

# %%
grads.plot(x='ShareWomen', y='Unemployment_rate', kind = 'scatter')

# %%
grads.plot(x='Men', y='Median', kind = 'scatter')

# %%
grads.plot(x='Women', y='Median', kind = 'scatter')

# %%
grads['Sample_size'].hist(bins=25, range=(0,5000), color='m')

# %%
grads['Median'].hist(bins=25, color='b')

# %% [markdown]
# From the histogram we can see that the most common median salary range is around $30,000.

# %%
grads['Employed'].hist(bins=25, range=(0,5000), color='green')

# %%
grads['Full_time'].hist(bins=25, range=(0,5000), color='gray')

# %%
grads['ShareWomen'].hist(bins=25, color='black')

# %%
mostly_female = grads['ShareWomen'] > 0.5

# %%
mostly_female.value_counts()
# Out:
# True     96
# False    76
# Name: ShareWomen, dtype: int64

# %% [markdown]
# From the data we can see approximately 80% of majors are predominately female, the remaining 20% are predominately male.

# %% [markdown]
# ## Scatter Matrices

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(grads[['Sample_size', 'Median']], figsize=(10,10), c='red')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4c770421d0>,
# ...
#       dtype=object)

# %%
scatter_matrix(grads[['Sample_size', 'Median', 'ShareWomen']], figsize=(10,10), c='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4c7724b9e8>,
# ...
#       dtype=object)

# %% [markdown]
# We can see from the scatter plot matrix that ShareWomen-Median is moderately negatively linearly correlated. Therefore Majors that are more popular with women tend to pay less.

# %% [markdown]
# ## Finding The Most Popular Majors

# %%
grads[:10].plot.barh(x='Major',y='ShareWomen')
plt.title('Proportion Of Women In The Ten Highest Paying Majors')
plt.xlabel('Percentage')
plt.ylabel('Major')
# Out:
# Text(0, 0.5, 'Major')

# %%
end = len(grads) - 10
grads[end:].plot.barh(x='Major',y='ShareWomen')
plt.title('Proportion Of Women In The Ten Lowest Paying Majors')
plt.xlabel('Percentage')
plt.ylabel('Major')
# Out:
# Text(0, 0.5, 'Major')

# %% [markdown]
# Women are under represented in the the highest paying majors, and over represented in the lowest paying majors.

# %%
grads[:10].plot.barh(x='Major',y='Unemployment_rate')
plt.title('Proportion Of Unemployed In The Ten Highest Paying Majors')
plt.xlabel('Percentage')
plt.ylabel('Major')
# Out:
# Text(0, 0.5, 'Major')

# %%
end = len(grads) - 10
grads[end:].plot.barh(x='Major',y='ShareWomen');
plt.title('Proportion Of Unemployed In The Ten Lowest Paying Majors')
plt.xlabel('Percentage')
plt.ylabel('Major')
# Out:
# Text(0, 0.5, 'Major')
